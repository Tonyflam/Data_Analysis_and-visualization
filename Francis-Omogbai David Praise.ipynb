# %%
import pandas as pd
import numpy as np

# %%
job = pd.read_csv("HRDataset_v14.csv", index_col = "EmpID")
job
# Out:
#                   Employee_Name  MarriedID  MaritalStatusID  GenderID  \
# EmpID
# 10026       Adinolfi, Wilson  K          0                0         1
# 10084  Ait Sidi, Karthikeyan             1                1         1
# 10196         Akinkuolie, Sarah          1                1         0
# 10088              Alagbe,Trina          1                1         0
# 10069          Anderson, Carol           0                2         0
# ...                         ...        ...              ...       ...
# 10135            Woodson, Jason          0                0         1
# 10301        Ybarra, Catherine           0                0         0
# 10010          Zamora, Jennifer          0                0         0
# 10043               Zhou, Julia          0                0         0
# 10271             Zima, Colleen          0                4         0
#
#        EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  \
# EmpID
# ...

# %%
highest_salaries = job.nlargest(15, 'Salary')
# highest_paid_employees_and_salaries = hr_data[['Employee_Name', highest_salaries, 'Position']].head(10)
# highest_paid_employees_and_salaries
highest_salaries[['Employee_Name', 'Salary', 'Position']]
# df_sorted = df.sort_values(by='column_name', ascending=False)
# Out:
#            Employee_Name  Salary                  Position
# EmpID
# 10089        King, Janet  250000           President & CEO
# 10010   Zamora, Jennifer  220450                       CIO
# 10272    Houlihan, Debra  180000         Director of Sales
# 10015        Foss, Jason  178000               IT Director
# 10019     Corleone, Vito  170500    Director of Operations
# 10288      Monroe, Peter  157000        IT Manager - Infra
# 10086       Roper, Katie  150290            Data Architect
# 10222      Ruiz, Ricardo  148999           IT Manager - DB
# 10198         Roup,Simon  140920           IT Manager - DB
# 10028      Dougall, Eric  138888      IT Manager - Support
# 10149   Roehrich, Bianca  120000  Principal Data Architect
# 10246      Goble, Taisha  114800    Database Administrator
# 10118    Voldemort, Lord  113999    Database Administrator
# 10108  Champaigne, Brian  110929               BI Director
# 10245      Becker, Renee  110000    Database Administrator

# %%
# High_atten= job.groupby(["Employee_Name"])['PerfScoreID'].agg(['sum'])
# High_atten.sort_values(by = "sum" , ascending = False)
filtered_job = job.loc[(job['PerfScoreID'] == 1) | (job['PerfScoreID'] == 2), :]
filtered_job["Employee_Name"]
# Out:
# EmpID
# 10294           Blount, Dianna
# 10292            Cole, Spencer
# 10282        Corleone, Michael
# 10311               Dee, Randy
# 10306            Delarge, Alex
# 10310          Desimone, Carl
# 10304        Dietrich, Jenna
# 10284           DiNocco, Lily
# 10299           Erilus, Angela
# 10280        Estremera, Miguel
# 10296           Evensen, April
# 10290           Exantus, Susan
# 10308      Fernandes, Nilson
# 10309               Fett, Boba
# 10283             Gilles, Alex
# 10300           Gonzalez, Juan
# 10289        Immediato, Walter
# 10298              Miller, Ned
# 10288            Monroe, Peter
# 10303             O'hare, Lynn
# 10281            Owad, Clinton
# 10286            Smith, Martin
# 10297        Pelletier, Ermine
# 10285         Robinson, Cherly
# 10295    Saar-Beckles, Melinda
# 10291              Smith, John
# 10302         Sparks, Taylor
# 10307       Stansfield, Norman
# 10287               Trang, Mei
# 10293         Wallace, Theresa
# ...

# %%
absent=job.Absences.value_counts()
absent
# Out:
# Absences
# 4     23
# 16    23
# 7     21
# 2     21
# 15    20
# 13    17
# 14    17
# 3     16
# 19    16
# 6     16
# 11    15
# 17    15
# 1     14
# 20    14
# 9     14
# 5     12
# 8     11
# 10    10
# 12     8
# 18     8
# Name: count, dtype: int64

# %%
Married_and_unmarried=job.MarriedID.value_counts()
print(Married_and_unmarried)
# Out:
# MarriedID
# 0    187
# 1    124
# Name: count, dtype: int64

# %% [markdown]
# So this means that 187 employees are not married and 124 are married

# %%
sp = job.loc[job['SpecialProjectsCount'].isin([6, 4, 5, 7, 3, 8, 2, 1]), :]
sp.SpecialProjectsCount.value_counts()
# Out:
# SpecialProjectsCount
# 6    21
# 5    21
# 7    12
# 4     9
# 3     3
# 8     2
# 2     1
# 1     1
# Name: count, dtype: int64

# %%
lowest_salaries = job.nsmallest(15, 'Salary')
# highest_paid_employees_and_salaries = hr_data[['Employee_Name', highest_salaries, 'Position']].head(10)
# highest_paid_employees_and_salaries
lowest_salaries[['Employee_Name', 'Salary', 'Position']]
# df_sorted = df.sort_values(by='column_name', ascending=False)
# Out:
#              Employee_Name  Salary                 Position
# EmpID
# 10271        Zima, Colleen   45046  Production Technician I
# 10236     Jacobi, Hannah     45069  Production Technician I
# 10058       Rhoads, Thomas   45115  Production Technician I
# 10219    Mahoney, Lauren     45395  Production Technician I
# 10170  Kirill, Alexandra     45433  Production Technician I
# 10171       Perry, Shakira   45998  Production Technician I
# 10052      Langton, Enrico   46120  Production Technician I
# 10207    Dobrin, Denisa  S   46335  Production Technician I
# 10260        Sadki, Nore     46428  Production Technician I
# 10262     Purinton, Janine   46430  Production Technician I
# 10208    Knapp, Bradley  J   46654  Production Technician I
# 10185          Ndzi, Horia   46664  Production Technician I
# 10011      Rivera, Haley     46738  Production Technician I
# 10187       Power, Morissa   46799  Production Technician I
# 10034      Johnson, George   46837  Production Technician I

# %%
recruitment= job.RecruitmentSource.value_counts()
recruitment.sort_values(ascending =True)
# Out:
# RecruitmentSource
# On-line Web application     1
# Other                       2
# Website                    13
# CareerBuilder              23
# Diversity Job Fair         29
# Employee Referral          31
# Google Search              49
# LinkedIn                   76
# Indeed                     87
# Name: count, dtype: int64

# %%
per= job.PerformanceScore.value_counts()
per
# Out:
# PerformanceScore
# Fully Meets          243
# Exceeds               37
# Needs Improvement     18
# PIP                   13
# Name: count, dtype: int64

# %%
emp = job['EmpSatisfaction'].value_counts()
emp
# Out:
# EmpSatisfaction
# 3    108
# 5     98
# 4     94
# 2      9
# 1      2
# Name: count, dtype: int64

# %%
recruitment.plot(x='RecruitmentSource', y ='mean', kind='barh', title= 'Recruitment Sources')
# Out:
# <Axes: title={'center': 'Recruitment Sources'}, ylabel='RecruitmentSource'>

# %%
per.plot(x='PerformanceScore', y ='mean', kind='barh', title = "Performance of employees" )
# Out:
# <Axes: title={'center': 'Performance of employees'}, ylabel='PerformanceScore'>

# %%
emp.plot(x='EmpSatisfaction', y ='mean', kind='barh', title = "Employees Satisfaction")
# Out:
# <Axes: title={'center': 'Employees Satisfaction'}, ylabel='EmpSatisfaction'>

# %% [markdown]
# HR Analytics - Employees Engagement:
#
# This project, focusing on an Employees Engagement Dataset, successfully conducted a comprehensive analysis using Python libraries. Notable findings include the identification of top earners, employees requiring attention, insights from absences, and the impact of marital status. Special project involvement and visualizations add depth to our understanding. The report concludes with actionable insights, empowering HR strategies and fostering employee well-being.
